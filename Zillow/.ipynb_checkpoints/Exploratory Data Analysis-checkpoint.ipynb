# %% [markdown]
# ### Load Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Dictionary

# %%
filepath ="Data/zillow_data_dictionary.csv"
data_dictionary = pd.read_csv(filepath)

# %%
#Increase column width for display
pd.options.display.max_colwidth = 125

# %%
data_dictionary
# Out:
#                            Feature  \
# 0          'airconditioningtypeid'
# 1       'architecturalstyletypeid'
# 2                   'basementsqft'
# 3                    'bathroomcnt'
# 4                     'bedroomcnt'
# 5          'buildingqualitytypeid'
# 6            'buildingclasstypeid'
# 7              'calculatedbathnbr'
# 8                     'decktypeid'
# 9            'threequarterbathnbr'
# 10      'finishedfloor1squarefeet'
# 11  'calculatedfinishedsquarefeet'
# 12           'finishedsquarefeet6'
# 13          'finishedsquarefeet12'
# 14          'finishedsquarefeet13'
# 15          'finishedsquarefeet15'
# 16          'finishedsquarefeet50'
# 17                          'fips'
# 18                  'fireplacecnt'
# 19                 'fireplaceflag'
# 20                   'fullbathcnt'
# 21                  'garagecarcnt'
# 22               'garagetotalsqft'
# 23                'hashottuborspa'
# 24         'heatingorsystemtypeid'
# ...

# %%
filepath_2 = "C:/Users/jmb179/Documents/My Stuff/Zillow Data/properties_2016.csv"
properties = pd.read_csv(filepath_2, low_memory = False)

# %%
print("The dimensions of the properties_2016 file are: ", properties.shape)
properties.head(5)
# Out:
# The dimensions of the properties_2016 file are:  (2985217, 58)
#    parcelid  airconditioningtypeid  architecturalstyletypeid  basementsqft  \
# 0  10754147                    NaN                       NaN           NaN
# 1  10759547                    NaN                       NaN           NaN
# 2  10843547                    NaN                       NaN           NaN
# 3  10859147                    NaN                       NaN           NaN
# 4  10879947                    NaN                       NaN           NaN
#
#    bathroomcnt  bedroomcnt  buildingclasstypeid  buildingqualitytypeid  \
# 0          0.0         0.0                  NaN                    NaN
# 1          0.0         0.0                  NaN                    NaN
# 2          0.0         0.0                  NaN                    NaN
# 3          0.0         0.0                  3.0                    7.0
# 4          0.0         0.0                  4.0                    NaN
#
# ...

# %%
filepath_3 = "Data/train_2016_v2.csv"
transactions = pd.read_csv(filepath_3)

# %%
print("The dimensions of the train_2016_v2 file are: ", transactions.shape)
transactions.head(5)
# Out:
# The dimensions of the train_2016_v2 file are:  (90275, 3)
#    parcelid  logerror transactiondate
# 0  11016594    0.0276      2016-01-01
# 1  14366692   -0.1684      2016-01-01
# 2  12098116   -0.0040      2016-01-01
# 3  12643413    0.0218      2016-01-02
# 4  14432541   -0.0050      2016-01-02

# %%
properties[properties.parcelid == 11016594]
# Out:
#          parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 2931667  11016594                    1.0                       NaN
#
#          basementsqft  bathroomcnt  bedroomcnt  buildingclasstypeid  \
# 2931667           NaN          2.0         3.0                  NaN
#
#          buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 2931667                    4.0                2.0         NaN
#
#                 ...           numberofstories  fireplaceflag  \
# 2931667         ...                       NaN            NaN
#
#          structuretaxvaluedollarcnt  taxvaluedollarcnt  assessmentyear  \
# 2931667                    122754.0           360170.0          2015.0
#
#          landtaxvaluedollarcnt  taxamount  taxdelinquencyflag  \
# 2931667               237416.0    6735.88                 NaN
#
#          taxdelinquencyyear  censustractandblock
# 2931667                 NaN         6.037107e+13
#
# [1 rows x 58 columns]
